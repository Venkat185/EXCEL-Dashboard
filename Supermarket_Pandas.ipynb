# %% [markdown]
# <a href="https://colab.research.google.com/github/Venkat185/EXCEL-Dashboard/blob/main/Supermarket_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/SUPERMARKET.xlsx')

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  765-26-6951      A     Yangon        Normal    Male
# 1  530-90-9855      A     Yangon        Member    Male
# 2  891-01-7034      B   Mandalay        Normal  Female
# 3  493-65-6248      C  Naypyitaw        Member  Female
# 4  556-97-7101      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 0       Sports and travel       72.61         6  21.783  457.443 2019-01-01
# 1      Home and lifestyle       47.59         8  19.036  399.756 2019-01-01
# 2  Electronic accessories       74.71         6  22.413  470.673 2019-01-01
# 3       Sports and travel       36.98        10  18.490  388.290 2019-01-01
# 4  Electronic accessories       63.22         2   6.322  132.762 2019-01-01
#
#        Time      Payment    COGS  Gross Margin Precentage  Gross Income  \
# 0  10:39:00  Credit card  435.66                 4.761905        21.783
# ...

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 995  642-61-4706      B   Mandalay        Member    Male
# 996  115-38-7388      C  Naypyitaw        Member  Female
# 997  291-55-6563      A     Yangon        Member  Female
# 998  361-85-2571      A     Yangon        Normal  Female
# 999  364-34-2972      C  Naypyitaw        Member    Male
#
#                Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 995      Food and beverages       93.40         2   9.340  196.140 2019-03-30
# 996     Fashion accessories       10.18         8   4.072   85.512 2019-03-30
# 997      Home and lifestyle       34.42         6  10.326  216.846 2019-03-30
# 998       Sports and travel       89.48         5  22.370  469.770 2019-03-30
# 999  Electronic accessories       96.82         3  14.523  304.983 2019-03-30
#
#          Time      Payment    COGS  Gross Margin Precentage  Gross Income  \
# 995  16:34:00         Cash  186.80                 4.761905         9.340
# ...

# %%
df.shape
# Out:
# (1000, 17)

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'COGS', 'Gross Margin Precentage', 'Gross Income',
#        'Rating'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[ns]
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total  \
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    15.379369   322.966749
# min      10.080000     1.000000     0.508500    10.678500
# 25%      32.875000     3.000000     5.924875   124.422375
# 50%      55.230000     5.000000    12.088000   253.848000
# 75%      77.935000     8.000000    22.445250   471.350250
# max      99.960000    10.000000    49.650000  1042.650000
# std      26.494628     2.923431    11.708825   245.885335
#
#                              Date        COGS  Gross Margin Precentage  \
# count                        1000  1000.00000             1.000000e+03
# mean   2019-02-14 00:05:45.600000   307.58738             4.761905e+00
# min           2019-01-01 00:00:00    10.17000             4.761905e+00
# 25%           2019-01-24 00:00:00   118.49750             4.761905e+00
# 50%           2019-02-13 00:00:00   241.76000             4.761905e+00
# ...

# %%
df.loc[0:1000 , "Product line": "Total"]
# Out:
#                Product line  Unit price  Quantity  Tax 5%    Total
# 0         Sports and travel       72.61         6  21.783  457.443
# 1        Home and lifestyle       47.59         8  19.036  399.756
# 2    Electronic accessories       74.71         6  22.413  470.673
# 3         Sports and travel       36.98        10  18.490  388.290
# 4    Electronic accessories       63.22         2   6.322  132.762
# ..                      ...         ...       ...     ...      ...
# 995      Food and beverages       93.40         2   9.340  196.140
# 996     Fashion accessories       10.18         8   4.072   85.512
# 997      Home and lifestyle       34.42         6  10.326  216.846
# 998       Sports and travel       89.48         5  22.370  469.770
# 999  Electronic accessories       96.82         3  14.523  304.983
#
# [1000 rows x 5 columns]

# %%
df.iloc[0:1001, 5:10]
# Out:
#                Product line  Unit price  Quantity  Tax 5%    Total
# 0         Sports and travel       72.61         6  21.783  457.443
# 1        Home and lifestyle       47.59         8  19.036  399.756
# 2    Electronic accessories       74.71         6  22.413  470.673
# 3         Sports and travel       36.98        10  18.490  388.290
# 4    Electronic accessories       63.22         2   6.322  132.762
# ..                      ...         ...       ...     ...      ...
# 995      Food and beverages       93.40         2   9.340  196.140
# 996     Fashion accessories       10.18         8   4.072   85.512
# 997      Home and lifestyle       34.42         6  10.326  216.846
# 998       Sports and travel       89.48         5  22.370  469.770
# 999  Electronic accessories       96.82         3  14.523  304.983
#
# [1000 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# COGS                       0
# Gross Margin Precentage    0
# Gross Income               0
# Rating                     0
# dtype: int64

# %%
df['Rating'].astype('int64')
# Out:
# 0      6
# 1      5
# 2      6
# 3      7
# 4      8
#       ..
# 995    5
# 996    9
# 997    7
# 998    7
# 999    6
# Name: Rating, Length: 1000, dtype: int64

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  765-26-6951      A     Yangon        Normal    Male
# 1  530-90-9855      A     Yangon        Member    Male
# 2  891-01-7034      B   Mandalay        Normal  Female
# 3  493-65-6248      C  Naypyitaw        Member  Female
# 4  556-97-7101      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 0       Sports and travel       72.61         6  21.783  457.443 2019-01-01
# 1      Home and lifestyle       47.59         8  19.036  399.756 2019-01-01
# 2  Electronic accessories       74.71         6  22.413  470.673 2019-01-01
# 3       Sports and travel       36.98        10  18.490  388.290 2019-01-01
# 4  Electronic accessories       63.22         2   6.322  132.762 2019-01-01
#
#        Time      Payment    COGS  Gross Margin Precentage  Gross Income  \
# 0  10:39:00  Credit card  435.66                 4.761905        21.783
# ...

# %%
df.sort_values(by = 'Unit price', ascending=False)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 761  219-22-9386      B   Mandalay        Member    Male    Sports and travel
# 241  148-41-7930      C  Naypyitaw        Normal    Male    Health and beauty
# 938  641-62-7288      B   Mandalay        Normal    Male   Home and lifestyle
# 630  437-53-3084      B   Mandalay        Normal    Male  Fashion accessories
# 699  667-92-0055      A     Yangon        Member    Male    Health and beauty
# ..           ...    ...        ...           ...     ...                  ...
# 996  115-38-7388      C  Naypyitaw        Member  Female  Fashion accessories
# 436  784-21-9238      C  Naypyitaw        Member    Male    Sports and travel
# 606  516-77-6464      C  Naypyitaw        Member  Female    Health and beauty
# 780  239-48-4278      A     Yangon        Member    Male   Food and beverages
# 980  333-23-2632      A     Yangon        Member    Male    Health and beauty
#
# ...

# %%
df.sort_values(by = 'Unit price', ascending=True)
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 980  333-23-2632      A     Yangon        Member    Male    Health and beauty
# 780  239-48-4278      A     Yangon        Member    Male   Food and beverages
# 606  516-77-6464      C  Naypyitaw        Member  Female    Health and beauty
# 436  784-21-9238      C  Naypyitaw        Member    Male    Sports and travel
# 996  115-38-7388      C  Naypyitaw        Member  Female  Fashion accessories
# ..           ...    ...        ...           ...     ...                  ...
# 699  667-92-0055      A     Yangon        Member    Male    Health and beauty
# 630  437-53-3084      B   Mandalay        Normal    Male  Fashion accessories
# 938  641-62-7288      B   Mandalay        Normal    Male   Home and lifestyle
# 241  148-41-7930      C  Naypyitaw        Normal    Male    Health and beauty
# 761  219-22-9386      B   Mandalay        Member    Male    Sports and travel
#
# ...

# %%
df.sort_values(by = ['Unit price', 'Total' ], ascending= [True, False])
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 980  333-23-2632      A     Yangon        Member    Male    Health and beauty
# 780  239-48-4278      A     Yangon        Member    Male   Food and beverages
# 606  516-77-6464      C  Naypyitaw        Member  Female    Health and beauty
# 436  784-21-9238      C  Naypyitaw        Member    Male    Sports and travel
# 996  115-38-7388      C  Naypyitaw        Member  Female  Fashion accessories
# ..           ...    ...        ...           ...     ...                  ...
# 699  667-92-0055      A     Yangon        Member    Male    Health and beauty
# 630  437-53-3084      B   Mandalay        Normal    Male  Fashion accessories
# 938  641-62-7288      B   Mandalay        Normal    Male   Home and lifestyle
# 761  219-22-9386      B   Mandalay        Member    Male    Sports and travel
# 241  148-41-7930      C  Naypyitaw        Normal    Male    Health and beauty
#
# ...

# %%
df.value_counts('Gender')
# Out:
# Gender
# Female    501
# Male      499
# Name: count, dtype: int64

# %%
df['Product line'].value_counts()
# Out:
# Product line
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: count, dtype: int64

# %%
df['Customer type'].value_counts()
# Out:
# Customer type
# Member    501
# Normal    499
# Name: count, dtype: int64

# %%
df['City'].value_counts()
# Out:
# City
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: count, dtype: int64

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  765-26-6951      A     Yangon        Normal    Male
# 1  530-90-9855      A     Yangon        Member    Male
# 2  891-01-7034      B   Mandalay        Normal  Female
# 3  493-65-6248      C  Naypyitaw        Member  Female
# 4  556-97-7101      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 0       Sports and travel       72.61         6  21.783  457.443 2019-01-01
# 1      Home and lifestyle       47.59         8  19.036  399.756 2019-01-01
# 2  Electronic accessories       74.71         6  22.413  470.673 2019-01-01
# 3       Sports and travel       36.98        10  18.490  388.290 2019-01-01
# 4  Electronic accessories       63.22         2   6.322  132.762 2019-01-01
#
#        Time      Payment    COGS  Gross Margin Precentage  Gross Income  \
# 0  10:39:00  Credit card  435.66                 4.761905        21.783
# ...

# %%
df.groupby(['Gender'])['Total'].sum()
# Out:
# Gender
# Female    167882.925
# Male      155083.824
# Name: Total, dtype: float64

# %%
df.groupby(['Gender'])['Total'].max()
# Out:
# Gender
# Female    1042.65
# Male      1039.29
# Name: Total, dtype: float64

# %%
df.groupby(['Gender'])['Total'].min()
# Out:
# Gender
# Female    12.6945
# Male      10.6785
# Name: Total, dtype: float64

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  765-26-6951      A     Yangon        Normal    Male
# 1  530-90-9855      A     Yangon        Member    Male
# 2  891-01-7034      B   Mandalay        Normal  Female
# 3  493-65-6248      C  Naypyitaw        Member  Female
# 4  556-97-7101      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 0       Sports and travel       72.61         6  21.783  457.443 2019-01-01
# 1      Home and lifestyle       47.59         8  19.036  399.756 2019-01-01
# 2  Electronic accessories       74.71         6  22.413  470.673 2019-01-01
# 3       Sports and travel       36.98        10  18.490  388.290 2019-01-01
# 4  Electronic accessories       63.22         2   6.322  132.762 2019-01-01
#
#        Time      Payment    COGS  Gross Margin Precentage  Gross Income  \
# 0  10:39:00  Credit card  435.66                 4.761905        21.783
# ...

# %%
df[(df['Total'] > 300) & (df['Payment'] == "Cash")]
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 1    530-90-9855      A     Yangon        Member    Male
# 2    891-01-7034      B   Mandalay        Normal  Female
# 6    651-88-7328      A     Yangon        Normal  Female
# 14   244-08-0162      B   Mandalay        Normal  Female
# 15   198-84-7132      B   Mandalay        Member    Male
# ..           ...    ...        ...           ...     ...
# 991  731-59-7531      B   Mandalay        Member    Male
# 992  676-39-6028      A     Yangon        Member  Female
# 994  778-89-7974      C  Naypyitaw        Normal    Male
# 998  361-85-2571      A     Yangon        Normal  Female
# 999  364-34-2972      C  Naypyitaw        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Total  \
# 1        Home and lifestyle       47.59         8  19.0360  399.7560
# 2    Electronic accessories       74.71         6  22.4130  470.6730
# 6       Fashion accessories       65.74         9  29.5830  621.2430
# ...

# %%
df["Valuable"] = "NO"
df.loc[(df["Total"] > 400) & (df["Payment"] == "Credit card"), "Valuable"] = "YES"

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  765-26-6951      A     Yangon        Normal    Male
# 1  530-90-9855      A     Yangon        Member    Male
# 2  891-01-7034      B   Mandalay        Normal  Female
# 3  493-65-6248      C  Naypyitaw        Member  Female
# 4  556-97-7101      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 0       Sports and travel       72.61         6  21.783  457.443 2019-01-01
# 1      Home and lifestyle       47.59         8  19.036  399.756 2019-01-01
# 2  Electronic accessories       74.71         6  22.413  470.673 2019-01-01
# 3       Sports and travel       36.98        10  18.490  388.290 2019-01-01
# 4  Electronic accessories       63.22         2   6.322  132.762 2019-01-01
#
#        Time      Payment    COGS  Gross Margin Precentage  Gross Income  \
# 0  10:39:00  Credit card  435.66                 4.761905        21.783
# ...

# %%
df['Valuable'].value_counts()
# Out:
# Valuable
# NO     900
# YES    100
# Name: count, dtype: int64

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  765-26-6951      A     Yangon        Normal    Male
# 1  530-90-9855      A     Yangon        Member    Male
# 2  891-01-7034      B   Mandalay        Normal  Female
# 3  493-65-6248      C  Naypyitaw        Member  Female
# 4  556-97-7101      C  Naypyitaw        Normal  Female
#
#              Product line  Unit price  Quantity  Tax 5%    Total       Date  \
# 0       Sports and travel       72.61         6  21.783  457.443 2019-01-01
# 1      Home and lifestyle       47.59         8  19.036  399.756 2019-01-01
# 2  Electronic accessories       74.71         6  22.413  470.673 2019-01-01
# 3       Sports and travel       36.98        10  18.490  388.290 2019-01-01
# 4  Electronic accessories       63.22         2   6.322  132.762 2019-01-01
#
#        Time      Payment    COGS  Gross Margin Precentage  Gross Income  \
# 0  10:39:00  Credit card  435.66                 4.761905        21.783
# ...

# %%
pd.pivot_table(data = df, index = 'Gender', columns = "Product line",  values = 'Quantity', aggfunc = 'sum')
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Gender
# Female                           488                  530                 514
# Male                             483                  372                 438
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Gender
# Female                      343                 498                496
# Male                        511                 413                424
